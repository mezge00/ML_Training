# %%
import pandas as pd
import sklearn 
from sklearn import svm, preprocessing 
df=pd.read_csv("datasets/diamonds.csv", index_col=0)
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df["cut"].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
#df["cut"].astype("category").cat.codes
cut_class_dict={"Fair":1, "Good":2, "Very Good":3, "Premium":4, "Ideal":5}
color_class_dict={"J":1, "I":2, "H":2, "G":3, "F":4, "E":5,"D":6}
clarity_class_dict={"I1":1, "SI2":2, "SI1":3, "VS2":4, "VS1":5, "VVS2":6, "VVS1":7, "IF":8}

# %%
df["cut"]=df["cut"].map(cut_class_dict)
df["color"]=df["color"].map(color_class_dict)
df["clarity"]=df["clarity"].map(clarity_class_dict)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 1   0.23    5      5        2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21    4      5        3   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23    2      5        5   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29    4      2        4   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31    2      1        2   63.3   58.0    335  4.34  4.35  2.75

# %%
df=sklearn.utils.shuffle(df)
X=df.drop("price",axis=1).values
Y=df["price"].values

# %%
X=preprocessing.scale(X)
test_size=200
x_train=X[:-test_size]
y_train=Y[:-test_size]
x_test=X[-test_size:]
y_test=Y[-test_size:]
# Out:
# SVR()

# %%
clf=svm.SVR(kernel="sigmoid")
clf.fit(x_train,y_train)
# Out:
# SVR(kernel='sigmoid')

# %%
clf.score(x_test,y_test)
# Out:
# 0.6463618417452432

# %%
for X,y in zip(x_test,y_test):
    print(f"Model:{clf.predict([X])[0]},Actual:{y}")
# Out:
# Model:1004.0994875066622,Actual:847
# Model:1840.7633142093275,Actual:1772
# Model:654.9083541145114,Actual:615
# Model:1460.1289397292403,Actual:789
# Model:5093.6522589752585,Actual:5226
# Model:2926.8306914175373,Actual:2281
# Model:1600.2326244774147,Actual:1642
# Model:1494.841950145947,Actual:1125
# Model:3104.40120201068,Actual:2359
# Model:6868.12597555761,Actual:10523
# Model:1046.206570993208,Actual:862
# Model:6104.806614965812,Actual:8315
# Model:4733.846052442542,Actual:4171
# Model:6774.015470976283,Actual:9408
# Model:869.7160435222545,Actual:1033
# Model:131.80125711333358,Actual:698
# Model:5287.968087139038,Actual:6272
# Model:4383.748585831467,Actual:2461
# Model:-98.07692039137237,Actual:471
# Model:1637.8411265443842,Actual:1752
# Model:5185.137925933208,Actual:5139
# Model:1426.067417136141,Actual:1421
# Model:1921.3332086881258,Actual:1814
# Model:193.14208938849742,Actual:749
# Model:403.8895431883775,Actual:799
# Model:5250.900032757983,Actual:5285
# ...
